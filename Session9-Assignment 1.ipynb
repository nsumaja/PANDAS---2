# %%
import numpy as np
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1) ## Delete Unnamed column
# Out:
#               Id       Name  Year Gender State  Count
# 0          11350       Emma  2004      F    AK     62
# 1          11351    Madison  2004      F    AK     48
# 2          11352     Hannah  2004      F    AK     46
# 3          11353      Grace  2004      F    AK     44
# 4          11354      Emily  2004      F    AK     41
# 5          11355    Abigail  2004      F    AK     37
# 6          11356     Olivia  2004      F    AK     33
# 7          11357   Isabella  2004      F    AK     30
# 8          11358     Alyssa  2004      F    AK     29
# 9          11359     Sophia  2004      F    AK     28
# 10         11360     Alexis  2004      F    AK     27
# 11         11361  Elizabeth  2004      F    AK     27
# 12         11362     Hailey  2004      F    AK     27
# 13         11363       Anna  2004      F    AK     26
# 14         11364    Natalie  2004      F    AK     25
# 15         11365      Sarah  2004      F    AK     25
# ...

# %%
df.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
df.groupby(['Gender']).Name.count() ## Distribution of Male & Female
# Out:
# Gender
# F    558846
# M    457549
# Name: Name, dtype: int64

# %%
df.groupby(['Gender', 'State']).size() ## Distribution of Male & Female by states
# Out:
# Gender  State
# F       AK        2404
#         AL        9878
#         AR        7171
#         AZ       14518
#         CA       45144
#         CO       11424
#         CT        6575
#         DC        3053
#         DE        2549
#         FL       25781
#         GA       19385
#         HI        3255
#         IA        7131
#         ID        4918
#         IL       21268
#         IN       13056
#         KS        7753
#         KY        8817
#         LA       10510
#         MA       10580
#         MD       11276
#         ME        2976
#         MI       16038
#         MN       10677
#         MO       11948
#         MS        7235
#         MT        2690
#         NC       17357
#         ND        2399
#         NE        5370
#                  ...
# M       ME        2777
#         MI       13243
#         MN        9004
#         MO        9917
#         MS        6862
#         MT        2986
#         NC       13530
#         ND        2581
# ...

# %%
df.Name.value_counts()[0:5] #Top 5 most preferred names.
# Out:
# Riley     1112
# Avery     1080
# Jordan    1073
# Peyton    1064
# Hayden    1049
# Name: Name, dtype: int64

# %%
MNameId = df['Id'].median()
MName = df[df['Id'] == MNameId]['Name']
print("Median name at index {} and is {}".format(MNameId, MName)) #Distribution of male and female born count by states
# Out:
# Median name at index 2811921.0 and is 508197    Kasey
# Name: Name, dtype: object
